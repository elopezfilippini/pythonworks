# %% [markdown]
# #Importacion de librerias

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import os

# %%
 dir = "C:/Users/BUCEFALO/Documents/Pyhthonworks/House Pricing Project"
#dir = "C:/Users/emi87/OneDrive/Documentos/Programacion/pythonworks/House Pricing Project"

# %%
file= "train.csv"
df= pd.read_csv(os.path.join(dir,file), index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_row", 100)

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
#mapa de nulos
plt.figure(figsize=(20, 10))  # Ajusta el tamaño del gráfico según tus necesidades
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Valores Nulos en el Conjunto de Datos')
plt.show()

# %% [markdown]
# #Data Exploration

# %% [markdown]
# ##Missing Data Handlig

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# MasVnrType        872
# FireplaceQu       690
# LotFrontage       259
# GarageYrBlt        81
# GarageCond         81
# GarageType         81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtCond           37
# BsmtQual           37
# BsmtFinType1       37
# MasVnrArea          8
# Electrical          1
# MSSubClass          0
# Fireplaces          0
# Functional          0
# KitchenQual         0
# KitchenAbvGr        0
# BedroomAbvGr        0
# HalfBath            0
# FullBath            0
# BsmtHalfBath        0
# TotRmsAbvGrd        0
# GarageCars          0
# GrLivArea           0
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
#Elimination of columns with too many null values.
df= df.drop(columns=
            ["Alley","MiscFeature","PoolQC","MasVnrType","FireplaceQu","Fence"])

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1           60       RL         65.0     8450   Pave      Reg         Lvl
# 2           20       RL         80.0     9600   Pave      Reg         Lvl
# 3           60       RL         68.0    11250   Pave      IR1         Lvl
# 4           70       RL         60.0     9550   Pave      IR1         Lvl
# 5           60       RL         84.0    14260   Pave      IR1         Lvl
#
#    Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# Id
# 1     AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 2     AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 3     AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 4     AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 5     AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
int_columns = df.select_dtypes(include=['int',"float"])

# %%
correlacionmapa=int_columns.corr()

# %%
plt.figure(figsize=(18, 12))  # Ajusta el tamaño del gráfico según tus necesidades
sns.heatmap(correlacionmapa, annot=True, cmap='coolwarm', linewidths=.5,fmt=".2f",annot_kws={"size": 5})
plt.title('Mapa de Correlación')
plt.show()

# %%
unnecesarycolumns=["LotConfig","Condition1","Condition2","HouseStyle","OverallQual","RoofStyle","RoofMatl","Exterior1st","Exterior2nd","ExterQual","Foundation","BsmtExposure","BsmtFinType1","BsmtFinSF1","BsmtFinType2","BsmtFinSF2","BsmtUnfSF",
                   "Heating","Electrical", "2ndFlrSF","BsmtFullBath","BsmtHalfBath","GarageType","GarageYrBlt","GarageFinish","GarageQual","GarageCond","OpenPorchSF","EnclosedPorch", "3SsnPorch","ScreenPorch"]

# %%
df=df.drop(columns=unnecesarycolumns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  BldgType       1460 non-null   object
#  11  OverallCond    1460 non-null   int64
#  12  YearBuilt      1460 non-null   int64
#  13  YearRemodAdd   1460 non-null   int64
#  14  MasVnrArea     1452 non-null   float64
#  15  ExterCond      1460 non-null   object
#  16  BsmtQual       1423 non-null   object
# ...

# %%
cat_columns = df.select_dtypes(exclude=['int', 'float'])

# %%
cat_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   Street         1460 non-null   object
#  2   LotShape       1460 non-null   object
#  3   LandContour    1460 non-null   object
#  4   Utilities      1460 non-null   object
#  5   LandSlope      1460 non-null   object
#  6   Neighborhood   1460 non-null   object
#  7   BldgType       1460 non-null   object
#  8   ExterCond      1460 non-null   object
#  9   BsmtQual       1423 non-null   object
#  10  BsmtCond       1423 non-null   object
#  11  HeatingQC      1460 non-null   object
#  12  CentralAir     1460 non-null   object
#  13  KitchenQual    1460 non-null   object
#  14  Functional     1460 non-null   object
#  15  PavedDrive     1460 non-null   object
#  16  SaleType       1460 non-null   object
# ...

# %%
type(cat_columns)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Analisis de Variables Categóricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  BldgType       1460 non-null   object
#  11  OverallCond    1460 non-null   int64
#  12  YearBuilt      1460 non-null   int64
#  13  YearRemodAdd   1460 non-null   int64
#  14  MasVnrArea     1452 non-null   float64
#  15  ExterCond      1460 non-null   object
#  16  BsmtQual       1423 non-null   object
# ...

# %%
cat_columns.columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LandSlope', 'Neighborhood', 'BldgType', 'ExterCond', 'BsmtQual',
#        'BsmtCond', 'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore")

# %%
fig, ax = plt.subplots(nrows=9, ncols=2, figsize=(20, 4*len(cat_columns.columns)))
fig.subplots_adjust(hspace=0.5)
ax = ax.ravel()  # Aplanar la matriz de ejes
 
# fig.subplots_adjust(hspace=1.0)

for i, col in enumerate(cat_columns.columns):
    sns.countplot(x=col, data=df, ax=ax[i])
    ax[i].set_title(col)
    ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=30)
    total = float(len(df))
    for p in ax[i].patches:
        height = p.get_height()
        ax[i].text(p.get_x() + p.get_width() / 2., height + 15, f'{height / total:.2%}', ha="center")


plt.show()

# %%
# Observaciones de los datos categoricos.¿: 
# "Street": Casi todos estan pavimentados --> Eliminar 
# "MsZoning": El 78% es RL
# "LandContour": el 89.79% son Lvl --> Eliminar
# "LotShape": "La mayoria son Regulares 63%" --> Separar eso de los irregulares con un mapeo
# "Utilities": Todas son allpub --> Eliminar 
# "BldgTYpe": Hay 5 tipos 1 fam contiene el 83.56% --> Mapear al restoc omo uno solo
# "Neighborhood": Son alrededor de 20. -->Hacer un dummies 
# "Extercood": TA contiene el 90% --> Mappear a otros el resto
# "BsmtQual":Dummies
# "BSmntCond": 90% de un estilo --> Elimnar 
# "HeatingQC": Hay 5 tipos --> dejarlo.
# "CentralAir": Variable predominante.  --> ELiminarlo
# "KitchenQual": Dummies
# "Functional": Variable predomninnte --> Elimnar
# "PavedDrive": Variable predominante -->Eliminar
# "Sale typ": 1 varibale predominate --> Elimnar
# "SaleCondition" Dejar Normal, partial el resto mandarlo a otros.

# %% [markdown]
# ###Eliminacion de Datos Categóricos Irrelevantes

# %%
IrrelevantCat=["Street","LandContour","MSZoning","Utilities","BsmtCond","CentralAir","Functional","PavedDrive", "SaleType"]

# %%
df=df.drop(columns=IrrelevantCat)

# %%
Cambiodenombres= {'MSSubClass': "SubclaseVivienda", 'LotFrontage':"FrenteLote", 'LotArea':"AreaLote", 'LotShape':"FormaLote", 'LandSlope':"InclinacionTerreno",
       'Neighborhood':"Vecindario", 'BldgType':"TipoVivienda", 'OverallCond':"Condiciones", 'YearBuilt':"AñoConstruccion", 'YearRemodAdd':"AñoRemodelacion",
       'MasVnrArea':"AreaConstruida", 'ExterCond':"CondicionesExternas", 'BsmtQual':"CondicinesSotano", 'TotalBsmtSF':"TotalMtsSotano", 'HeatingQC':"CalefaccionCalidad",
       '1stFlrSF':"PrimerPisoMts", 'LowQualFinSF':"PisosBajacalidad", 'GrLivArea':"AreaSotano", 'FullBath':"BañoCompleto", 'HalfBath':"BañoParcial",
       'BedroomAbvGr':"HabSubsuelo", 'KitchenAbvGr':"CocinaSubsuelo", 'KitchenQual':"CocinaCalidad", 'TotRmsAbvGrd':"TotalCuartosBS",
       'Fireplaces':"Hogares", 'GarageCars':"EspacioGarage", 'GarageArea':"AreaGarage", 'WoodDeckSF':"Deck", 'PoolArea':"AreaPiscina",
       'MiscVal':"ValuacionAmennities", 'MoSold':"Mesvendido", 'YrSold':"AñoVendido", 'SaleCondition':"CondicionVenta", 'SalePrice':"Precio"}

# %%
# Cambio de Nombre de Columnas
df.rename(columns=Cambiodenombres,inplace=True)

# %%
# no borrar "OverallQual"
# "Yearbuilt"
# "MasVnrArea"
# "TotalBsmtSF"
# "1stFlrSF"
# "GrLivArea"
# "FullBath"
# "TotRmsAbvGrd"
# "Fireplaces"
# "GarageCars"

# %%
variablesnumericas= df.select_dtypes(include=[int,float])
variablesnumericas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SubclaseVivienda     1460 non-null   int64
#  1   FrenteLote           1201 non-null   float64
#  2   AreaLote             1460 non-null   int64
#  3   Condiciones          1460 non-null   int64
#  4   AñoConstruccion      1460 non-null   int64
#  5   AñoRemodelacion      1460 non-null   int64
#  6   AreaConstruida       1452 non-null   float64
#  7   TotalMtsSotano       1460 non-null   int64
#  8   PrimerPisoMts        1460 non-null   int64
#  9   PisosBajacalidad     1460 non-null   int64
#  10  AreaSotano           1460 non-null   int64
#  11  BañoCompleto         1460 non-null   int64
#  12  BañoParcial          1460 non-null   int64
#  13  HabSubsuelo          1460 non-null   int64
#  14  CocinaSubsuelo       1460 non-null   int64
# ...

# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# ...

# %%
variablesnumericas.FrenteLote.dropna(inplace=True)
variablesnumericas.AreaConstruida.dropna(inplace=True)

# %%
pip install --upgrade matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# ...

# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\bucefalo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\bucefalo\anaconda3\lib\site-packages)
# ...

# %%
# Define el tamaño de fuente para los ticks
tick_fontsize = 8

# Calcular el número de filas y columnas en función del número de columnas
n_columns = len(variablesnumericas.columns)
n_rows = (n_columns + 1) // 2  # Para manejar un número impar de columnas

# Crear una figura con el número adecuado de subplots
fig, axs = plt.subplots(nrows=n_rows, ncols=2, figsize=(20, 60))

for i, column in enumerate(variablesnumericas.columns):
    if variablesnumericas[column].dtype == 'int64':
        # Gráfico de barras para variables enteras
        row = i // 2  # Calcular la fila correspondiente
        col = i % 2   # Calcular la columna correspondiente
        axs[row, col].bar(variablesnumericas[column].value_counts().index, variablesnumericas[column].value_counts())
        axs[row, col].set_title(f'Gráfico de Barras de {column}')
        axs[row, col].set_xlabel('Valor', fontsize=14)
        axs[row, col].set_ylabel('Frecuencia', fontsize=14)

        # Ajusta el tamaño de fuente de los ticks del eje x e y
        axs[row, col].tick_params(axis='both', labelsize=tick_fontsize)

plt.tight_layout()  # Ajusta automáticamente el espaciado entre subplots
plt.show()

# %% [markdown]
# ##Normality Tests for continous variables:

# %%
from scipy import stats
columnascontinuas= ["FrenteLote","AreaConstruida"]
# The normality of both variables is rejected
for i in columnascontinuas:
    print (f'Variables values are   {i}  skewness : {df[i].skew()}  y Kurtosis :  {df[i].kurtosis()} Shapiro values are {stats.shapiro(df[i].dropna())}')
# Out:
# Variables values are   FrenteLote  skewness : 2.163569142324884  y Kurtosis :  17.452867259818404 Shapiro values are ShapiroResult(statistic=0.880405843257904, pvalue=2.003058021981976e-29)
# Variables values are   AreaConstruida  skewness : 2.669084210182863  y Kurtosis :  10.08241731736711 Shapiro values are ShapiroResult(statistic=0.6392855048179626, pvalue=0.0)

# %% [markdown]
# ##Data description:

# %% [markdown]
# #Cleaning

# %% [markdown]
# Desarrollo de Pipelines:
# a. Para las variables tipo objeto
#     1. Realizar Un pipeline para que se mapeen las variables relevante.
#     2. Establecer un One Hot encoder para cada una.
# b. Para las variables tipo numericas:
#     1. Establecer una media para Frente Lote.
#     2. Establecer una media para Area Lote.

# %%
Columnasobjeto=['FormaLote', 'InclinacionTerreno', 'Vecindario', 'TipoVivienda',
       'CondicionesExternas', 'CondicinesSotano', 'CalefaccionCalidad',
       'CocinaCalidad', 'CondicionVenta']

# %%
df.columns
# Out:
# Index(['SubclaseVivienda', 'FrenteLote', 'AreaLote', 'FormaLote',
#        'InclinacionTerreno', 'Vecindario', 'TipoVivienda', 'Condiciones',
#        'AñoConstruccion', 'AñoRemodelacion', 'AreaConstruida',
#        'CondicionesExternas', 'CondicinesSotano', 'TotalMtsSotano',
#        'CalefaccionCalidad', 'PrimerPisoMts', 'PisosBajacalidad', 'AreaSotano',
#        'BañoCompleto', 'BañoParcial', 'HabSubsuelo', 'CocinaSubsuelo',
#        'CocinaCalidad', 'TotalCuartosBS', 'Hogares', 'EspacioGarage',
#        'AreaGarage', 'Deck', 'AreaPiscina', 'ValuacionAmennities',
#        'Mesvendido', 'AñoVendido', 'CondicionVenta', 'Precio'],
#       dtype='object')

# %%
# pip install scikit-learn

# %%
from sklearn.base import (BaseEstimator, TransformerMixin)
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

class mapeo(BaseEstimator, TransformerMixin):
    def __init(self):
       pass
    def fit(self, x):
       return self
    def transform(self, x):
      x["CondicionVenta"] = x["CondicionVenta"].map({"Partial": "Otros", "Abnorml": "Otros","Family":"Otros","Alloca":"Otros","AdjLand":"Otros","Normal":"Normal"}) 
      x["CalefaccionCalidad"] = x["CalefaccionCalidad"].map({"Ex": "Ex", "TA": "TA","Gd":"Otros","Fa":"Otros","Po":"Otros"})
      x["InclinacionTerreno"]= x["InclinacionTerreno"].map({"Gtl": "Gtl", "Mod": "Otros","Sev":"Otros"})
      x["CondicionesExternas"]= x["CondicionesExternas"].map({"TA": "TA", "Gd": "Otros","Fa":"Otros","Ex":"Otros","Po":"Otros"})
      return x
    
class Hot(BaseEstimator, TransformerMixin):
    def __init(self):
       pass
    def fit(self, x):
       return self
    def transform(self, x):
      ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)
      columns_to_encode = ["FormaLote", "InclinacionTerreno", "Vecindario", "TipoVivienda", "CondicionesExternas", "CondicinesSotano", "CalefaccionCalidad", "CocinaCalidad", "CondicionVenta"]
      encoded_dataframes = []  # Declarar la lista de DataFrames
      for column in columns_to_encode:
         transformed_data = ohe.fit_transform(x[[column]])
         feature_names = ohe.get_feature_names_out(input_features=[column])
         encoded_dataframe = pd.DataFrame(transformed_data, columns=feature_names)
         encoded_dataframes.append(encoded_dataframe)
      p = pd.concat(encoded_dataframes, axis=1) 
      x = pd.concat([x, p], axis=1)

      # a=pd.DataFrame(ohe.fit_transform(x["FormaLote"].values.reshape(-1,1)))
      # b=pd.DataFrame(ohe.fit_transform(x["InclinacionTerreno"].values.reshape(-1,1)))
      # c=pd.DataFrame(ohe.fit_transform(x["Vecindario"].values.reshape(-1,1)))
      # d=pd.DataFrame(ohe.fit_transform(x["TipoVivienda"].values.reshape(-1,1)))
      # e=pd.DataFrame(ohe.fit_transform(x["CondicionesExternas"].values.reshape(-1,1)))
      # f=pd.DataFrame(ohe.fit_transform(x["CondicinesSotano"].values.reshape(-1,1)))
      # g=pd.DataFrame(ohe.fit_transform(x["CalefaccionCalidad"].values.reshape(-1,1)))
      # h=pd.DataFrame(ohe.fit_transform(x["CocinaCalidad"].values.reshape(-1,1)))
      # i=pd.DataFrame(ohe.fit_transform(x["CondicionVenta"].values.reshape(-1,1)))

      x.drop(columns= ['FormaLote', 'InclinacionTerreno', 'Vecindario', 'TipoVivienda',
       'CondicionesExternas', 'CondicinesSotano', 'CalefaccionCalidad',
       'CocinaCalidad', 'CondicionVenta'], inplace=True)
    
      return x 
class nulos(BaseEstimator, TransformerMixin):
    def __init(self):
       pass
    def fit(self, x):
       return self
    def transform(self, x):
      imputer = SimpleImputer(strategy="mean")
      x["FrenteLote"] = imputer.fit_transform(x[["FrenteLote"]])
      x["AreaConstruida"] = imputer.fit_transform(x[["AreaConstruida"]])
      x= x.dropna()
      return x

# %%
df.columns
# Out:
# Index(['SubclaseVivienda', 'FrenteLote', 'AreaLote', 'FormaLote',
#        'InclinacionTerreno', 'Vecindario', 'TipoVivienda', 'Condiciones',
#        'AñoConstruccion', 'AñoRemodelacion', 'AreaConstruida',
#        'CondicionesExternas', 'CondicinesSotano', 'TotalMtsSotano',
#        'CalefaccionCalidad', 'PrimerPisoMts', 'PisosBajacalidad', 'AreaSotano',
#        'BañoCompleto', 'BañoParcial', 'HabSubsuelo', 'CocinaSubsuelo',
#        'CocinaCalidad', 'TotalCuartosBS', 'Hogares', 'EspacioGarage',
#        'AreaGarage', 'Deck', 'AreaPiscina', 'ValuacionAmennities',
#        'Mesvendido', 'AñoVendido', 'CondicionVenta', 'Precio'],
#       dtype='object')

# %%
df.isnull().sum().loc[lambda x: x != 0]
# Out:
# FrenteLote             259
# InclinacionTerreno      78
# AreaConstruida           8
# CondicionesExternas    178
# CondicinesSotano        37
# CalefaccionCalidad     291
# CondicionVenta         262
# dtype: int64

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ("a", mapeo()),
    ("b", Hot()),
    ("c", nulos())])

# %%
nuevadf=pipeline.fit_transform(df)

# %% [markdown]
# ##Predicciones

# %% [markdown]
# ###Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
#Definiccion de variable a predecir y predictore
X = nuevadf.drop(columns="Precio")
y = nuevadf["Precio"]

# %%
#Train and Test division
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30, random_state = 42)

# %% [markdown]
# a)Linear Regression

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
std_scaler= MinMaxScaler()
xltrain,xltest = np.copy(X_train),np.copy(X_test)
xltrain= std_scaler.fit_transform(xltrain)
xltest= std_scaler.fit_transform(xltest)

Lregres=LinearRegression()
Lregres.fit(xltrain,y_train)
predicciones = Lregres.predict(xltrain)
predicciontest= Lregres.predict(xltest)
mae= mean_absolute_error(predicciones,y_train)
mae2= mean_absolute_error(predicciontest,y_test)
print (f'error mean absolute for training is : {mae}, error mean absolute for test is: {mae2}')
# Out:
# error mean absolute for training is : 24371.76885406464, error mean absolute for test is: 57266.49771689498

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

reg= DecisionTreeRegressor()
reg.fit(X_train,y_train)
predicciones = reg.predict(X_train)
predicciontest= reg.predict(X_test)

mae= mean_absolute_error(predicciones,y_train)
mae2= mean_absolute_error(predicciontest,y_test)
print (f'error mean absolute for training is : {mae}, error mean absolute for test is: {mae2}')
# Out:
# error mean absolute for training is : 0.0, error mean absolute for test is: 29295.924657534248

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

reg= RandomForestRegressor()
reg.fit(X_train,y_train)
predicciones = reg.predict(X_train)
predicciontest= reg.predict(X_test)

mae= mean_absolute_error(predicciones,y_train)
mae2= mean_absolute_error(predicciontest,y_test)
print (f'error mean absolute for training is : {mae}, error mean absolute for test is: {mae2}')
# Out:
# error mean absolute for training is : 7620.513643486778, error mean absolute for test is: 18984.31216894977
